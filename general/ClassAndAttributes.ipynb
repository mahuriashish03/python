# %%
class Dog():
    def __init__(self,mybreed, name, spots):
        self.mybreed = mybreed
        self.name = name
        self.spots = spots

# %%
my_dog = Dog(mybreed= "Lab", name = "Shiro", spots = True)

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.mybreed
# Out:
# 'Lab'

# %%
my_dog.name
# Out:
# 'Shiro'

# %%
my_dog

# %%
my_dog

# %%
my_dog.spots
# Out:
# True

# %%
class Cat():

    species = "mammel"
    def __init__(self,mybreed, name, spots):
        self.mybreed = mybreed
        self.name = name
        self.spots = spots

# %%
my_cat = Cat(mybreed="Russian", name="katy", spots = False)

# %%
type(my_cat)
# Out:
# __main__.Cat

# %%
my_cat.mybreed
# Out:
# 'Russian'

# %%
my_cat.name
# Out:
# 'katy'

# %%
my_cat.spots
# Out:
# False

# %%
my_cat.species
# Out:
# 'mammel'
